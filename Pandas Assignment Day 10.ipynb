# %% [markdown]
# # <center>Pandas Assignment</center>

# %% [markdown]
# Import pandas and numpy with their aliases

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Create a variable a = pd.Series([ 100, 200, 300, 400])

# %%
a = pd.Series([100, 200, 300, 400])

# %% [markdown]
# Print a, and data type

# %%
print(a)
print("Data type:", a.dtype)
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64
# Data type: int64

# %% [markdown]
# Using indexing access the element 300 from the series a.

# %%
print("Element at index 2:", a[2])
# Out:
# Element at index 2: 300

# %% [markdown]
# What are the values of index for series a?

# %%
print("Index values:", a.index)
# Out:
# Index values: RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# Change the index to  ['c', 'a', 'b', 'd']

# %%
a.index = ['c', 'a', 'b', 'd']
print("Series with new index:\n", a)
# Out:
# Series with new index:
#  c    100
# a    200
# b    300
# d    400
# dtype: int64

# %% [markdown]
# Access the value in the series with index 'd'

# %%
print("Value at index 'd':", a['d'])
# Out:
# Value at index 'd': 400

# %% [markdown]
# Sort the values wrt to the index and print it

# %%
print("Sorted by index:\n", a.sort_index())
# Out:
# Sorted by index:
#  a    200
# b    300
# c    100
# d    400
# dtype: int64

# %% [markdown]
# Create a new Pandas Series b having index as 'e', 'f', and 'g' and value 800,450,100 and print it

# %%
b = pd.Series([800, 450, 100], index=['e', 'f', 'g'])
print("Series b:\n", b)
# Out:
# Series b:
#  e    800
# f    450
# g    100
# dtype: int64

# %% [markdown]
# Append b series at the end of a series

# %%
a = pd.concat([a, b])
print("Series a after appending b:\n", a)
# Out:
# Series a after appending b:
#  c    100
# a    200
# b    300
# d    400
# e    800
# r    450
# g    100
# dtype: int64

# %%
#print a again after appending b into it

print(a)
# Out:
# c    100
# a    200
# b    300
# d    400
# e    800
# r    450
# g    100
# dtype: int64

# %% [markdown]
# Sort the values in descending order of a and print the index of the sorted series

# %%
a_sorted = a.sort_values(ascending=False)
print("Series a sorted by values (descending):\n", a_sorted)
# Out:
# Series a sorted by values (descending):
#  e    800
# r    450
# d    400
# b    300
# a    200
# c    100
# g    100
# dtype: int64

# %%
print("Index of sorted series:\n", a_sorted.index)
# Out:
# Index of sorted series:
#  Index(['e', 'r', 'd', 'b', 'a', 'c', 'g'], dtype='str')

# %% [markdown]
# ## Pandas DataFrame

# %% [markdown]
# ### Part 1

# %% [markdown]
# Create a pandas dataframe df from the series 'a' that we used in the last section, print the dataframe

# %%
import pandas as pd

df = pd.DataFrame(a, columns=['values'])
print("DataFrame df:\n", df)
# Out:
# DataFrame df:
#     values
# c     100
# a     200
# b     300
# d     400
# e     800
# r     450
# g     100

# %%
print("DataFrame df:\n", df)
# Out:
# DataFrame df:
#     values
# c     100
# a     200
# b     300
# d     400
# e     800
# r     450
# g     100

# %% [markdown]
# What is the shape of the datafarme <br>
# (also, what does it imply?)

# %%
print("Shape of df:", df.shape)
# Out:
# Shape of df: (7, 1)

# %% [markdown]
# Hey! remember shape (7,1) implies dataframe has 7 rows and 1 column.

# %% [markdown]
# What is the index of the dataframe, is it same as the series 'a'

# %%
# yep its same as the series.

print("Index of df:", df.index)
# Out:
# Index of df: Index(['c', 'a', 'b', 'd', 'e', 'r', 'g'], dtype='str')

# %% [markdown]
# print the head and tail of the dataframe. <br>
# Additional - (what does head and tali represent?)

# %%
print("Head of df:\n", df.head())
# Out:
# Head of df:
#     values
# c     100
# a     200
# b     300
# d     400
# e     800

# %%
print("Tail of df:\n", df.tail())
# Out:
# Tail of df:
#     values
# b     300
# d     400
# e     800
# r     450
# g     100

# %% [markdown]
# Rename the column of the dataframe as 'points'

# %%
df.rename(columns={'values': 'points'}, inplace=True)
print("DataFrame with renamed column:\n", df)
# Out:
# DataFrame with renamed column:
#     points
# c     100
# a     200
# b     300
# d     400
# e     800
# r     450
# g     100

# %% [markdown]
# Create another Series 'fruits', which contains random names of fruits from ['orange','mango','apple']. The series should contain 7 elements, randomly selected from ['orange','mango','apple']

# %%
#Create fruits array

fruits_array = np.random.choice(['orange', 'mango', 'apple'], size=7)
print("Fruits array:\n", fruits_array)
# Out:
# Fruits array:
#  ['apple' 'mango' 'mango' 'orange' 'orange' 'apple' 'mango']

# %%
#Create series fruits out of fruits array

fruits = pd.Series(fruits_array)
print("Fruits series before reindexing:\n", fruits)
# Out:
# Fruits series before reindexing:
#  0     apple
# 1     mango
# 2     mango
# 3    orange
# 4    orange
# 5     apple
# 6     mango
# dtype: str

# %% [markdown]
# Change the index of fruits to the index of dataframe df

# %%
fruits.index = df.index
print("Fruits series with df index:\n", fruits)
# Out:
# Fruits series with df index:
#  c     apple
# a     mango
# b     mango
# d    orange
# e    orange
# r     apple
# g     mango
# dtype: str

# %% [markdown]
# Add this fruits series as a new column to the dataframe df with its column name as 'fruits'
# <br>print the head of the dataframe to verify

# %%
df['fruits'] = fruits
print("Head of dataframe with fruits column:\n", df.head())
# Out:
# Head of dataframe with fruits column:
#     points  fruits
# c     100   apple
# a     200   mango
# b     300   mango
# d     400  orange
# e     800  orange

# %% [markdown]
# ## Pandas Concatenation

# %% [markdown]
# Create a dataframe  d1 where the cols are  ‘city’ : [‘Chandigarh’, ‘Delhi’, ‘Kanpur’, ‘Chennai’, ‘Manali’ ] and ‘Temperature’ : [15, 22, 20, 26,-2]

# %%
d1 = pd.DataFrame({
     'city':['Chandigarh', 'Delhi', 'Kanpur', 'Chennai', 'Manali'],
     'Temperature':[15,22,20,26,-2]
    })

# %% [markdown]
# Print(d1)

# %%
print("DataFrame d1:\n", d1)
# Out:
# DataFrame d1:
#           city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22
# 2      Kanpur           20
# 3     Chennai           26
# 4      Manali           -2

# %% [markdown]
# What is the shape of d1.

# %%
print("Shape of d1:", d1.shape)
# Out:
# Shape of d1: (5, 2)

# %% [markdown]
# Set city = d1['city']

# %%
city = d1['city']
print("City column:\n", city)
# Out:
# City column:
#  0    Chandigarh
# 1         Delhi
# 2        Kanpur
# 3       Chennai
# 4        Manali
# Name: city, dtype: str

# %% [markdown]
# print city <br>
# What is the type of city.

# %%
print("Type of city:", type(city))
# Out:
# Type of city: <class 'pandas.Series'>

# %% [markdown]
# Create another datafeame 'd2' where the columns are <br>
# 'city' - ['Bengalaru','Coimbatore','Srirangam','Pondicherry'] <br>
# 'Temperature' - [24,35,36,39]

# %%
d2 = pd.DataFrame({
    'city': ['Bengaluru','Coimbatore','Srirangam','Pondicherry'],
    'Temperature': [24, 35, 36, 39]
})
# Out:
#           city  Temperature
# 0    Bengaluru           24
# 1   Coimbatore           35
# 2    Srirangam           36
# 3  Pondicherry           39

# %% [markdown]
# print the shape of this dataframe

# %%
print("Shape of d2:", d2.shape)
# Out:
# Shape of d2: (4, 2)

# %% [markdown]
# merge the two dataframes together, save it in a new dataframe named 'd3'

# %%
d3 = pd.concat([d1, d2], ignore_index=True)
print("\nMerged dataframe (d3):\n", d3)
# Out:
# Merged dataframe (d3):
#            city  Temperature
# 0   Chandigarh           15
# 1        Delhi           22
# 2       Kanpur           20
# 3      Chennai           26
# 4       Manali           -2
# 5    Bengaluru           24
# 6   Coimbatore           35
# 7    Srirangam           36
# 8  Pondicherry           39

# %% [markdown]
# Select the part of the dataframe such that it contains cities wherer temp is less then or equal to 20 <br>
# How many cities are there?

# %%
low_temp = d3[d3['Temperature'] <= 20]
print("\nCities with temp <= 20:\n", low_temp)
print("Number of cities with temp <= 20:", low_temp.shape[0])
# Out:
# Cities with temp <= 20:
#           city  Temperature
# 0  Chandigarh           15
# 2      Kanpur           20
# 4      Manali           -2
# Number of cities with temp <= 20: 3

# %% [markdown]
# Select the part of the dataframe such that it contains the cities where tempearature greater than or equal to 35

# %%
high_temp = d3[d3['Temperature'] >= 35]
print("\nCities with temp >= 35:\n", high_temp)
# Out:
# Cities with temp >= 35:
#            city  Temperature
# 6   Coimbatore           35
# 7    Srirangam           36
# 8  Pondicherry           39

# %% [markdown]
# ## Applying functions to columns and creating new columns

# %% [markdown]
# We need to create another column in d3, which contains  a boolean value for each city to indicate whether it's a union territory or not.
# - HINT: Chandigarh, Pondicherry and Delhi are only 3 union territories here.

# %%
# write function here

#def is_ut(x):
d3['is_ut'] = d3['city'].apply(lambda x: x in ['Chandigarh', 'Pondicherry', 'Delhi'])

#     # write code below


print(d3)
# Out:
#           city  Temperature  is_ut
# 0   Chandigarh           15   True
# 1        Delhi           22   True
# 2       Kanpur           20  False
# 3      Chennai           26  False
# 4       Manali           -2  False
# 5    Bengaluru           24  False
# 6   Coimbatore           35  False
# 7    Srirangam           36  False
# 8  Pondicherry           39   True

# %%
# print d3
print(d3)
# Out:
#           city  Temperature  is_ut
# 0   Chandigarh           15   True
# 1        Delhi           22   True
# 2       Kanpur           20  False
# 3      Chennai           26  False
# 4       Manali           -2  False
# 5    Bengaluru           24  False
# 6   Coimbatore           35  False
# 7    Srirangam           36  False
# 8  Pondicherry           39   True

# %% [markdown]
# The temperatures mentioned in ‘Temperature’ column are mentioned in Celsius, we need another column which contains the same in Fahrenheit.

# %% [markdown]
# HINT -
# - Define a function c_to_f which takes input temp in celsius and returns a value with temperature in Fahrenheit.
# - To check: c_to_f(10) should return 50.

# %%
# write function here
def c_to_f(temp_c):
    return (temp_c * 9/5) + 32

# %%
# check function c_to_f(10)
print("c_to_f(10) =", c_to_f(10))
# Out:
# c_to_f(10) = 50.0

# %%
# apply function c_to_f to d3 to create a column 'temp_farenhiet'

d3['temp_fahrenheit'] = d3['Temperature'].apply(c_to_f)

print("\nFinal dataframe:\n", d3)
# Out:
# Final dataframe:
#            city  Temperature  is_ut  temp_fahrenheit
# 0   Chandigarh           15   True             59.0
# 1        Delhi           22   True             71.6
# 2       Kanpur           20  False             68.0
# 3      Chennai           26  False             78.8
# 4       Manali           -2  False             28.4
# 5    Bengaluru           24  False             75.2
# 6   Coimbatore           35  False             95.0
# 7    Srirangam           36  False             96.8
# 8  Pondicherry           39   True            102.2

# %% [markdown]
# ## Indexing and selecting rows in DataFrame

# %% [markdown]
# Select subset of the dataframe d1 such that it contains the cities which are union territories.

# %%
d1 = pd.DataFrame({
    'city': ['Chandigarh','Delhi','Kanpur','Chennai','Manali','Bengaluru','Coimbatore','Srirangam','Pondicherry'],
    'Temperature': [15,22,20,26,-2,24,35,36,39],
    'is_ut': [True, True, False, False, False, False, False, False, True],
    'temp_fahrenheit': [(15*9/5)+32, (22*9/5)+32, (20*9/5)+32, (26*9/5)+32, (-2*9/5)+32,
                        (24*9/5)+32, (35*9/5)+32, (36*9/5)+32, (39*9/5)+32]
})

# %% [markdown]
# Select a subset of the dataframe d1 such that it contains the cities which only have temperature above 90 Farenhiet.

# %%
ut_subset = d1[d1['is_ut'] == True]
print("\nUnion Territories:\n", ut_subset)

hot_subset = d1[d1['temp_fahrenheit'] > 90]
print("\nCities above 90°F:\n", hot_subset)
# Out:
# Union Territories:
#            city  Temperature  is_ut  temp_fahrenheit
# 0   Chandigarh           15   True             59.0
# 1        Delhi           22   True             71.6
# 8  Pondicherry           39   True            102.2
#
# Cities above 90°F:
#            city  Temperature  is_ut  temp_fahrenheit
# 6   Coimbatore           35  False             95.0
# 7    Srirangam           36  False             96.8
# 8  Pondicherry           39   True            102.2

# %% [markdown]
# Select only the first three rows of the dataframe d1.

# %%
first_three = d1.head(3)
print("\nFirst three rows:\n", first_three)
# Out:
# First three rows:
#           city  Temperature  is_ut  temp_fahrenheit
# 0  Chandigarh           15   True             59.0
# 1       Delhi           22   True             71.6
# 2      Kanpur           20  False             68.0

# %% [markdown]
# Select all the rows and last two columns in the dataframe.

# %%
last_two_cols = d1.iloc[:, -2:]
print("\nAll rows, last two columns:\n", last_two_cols)
# Out:
# All rows, last two columns:
#     is_ut  temp_fahrenheit
# 0   True             59.0
# 1   True             71.6
# 2  False             68.0
# 3  False             78.8
# 4  False             28.4
# 5  False             75.2
# 6  False             95.0
# 7  False             96.8
# 8   True            102.2

# %% [markdown]
# ## Groupby

# %%
# Create a dataframe using dictionary of your choice

data = {
    'city': ['Delhi','Delhi','Chennai','Chennai','Pondicherry','Pondicherry','Delhi','Chennai'],
    'sales': [100,200,150,250,300,400,120,180],
    'employees': [10,15,12,18,20,25,14,16]
}
df = pd.DataFrame(data)
print("Original dataframe:\n", df)
# Out:
# Original dataframe:
#            city  sales  employees
# 0        Delhi    100         10
# 1        Delhi    200         15
# 2      Chennai    150         12
# 3      Chennai    250         18
# 4  Pondicherry    300         20
# 5  Pondicherry    400         25
# 6        Delhi    120         14
# 7      Chennai    180         16

# %%
# Use Groupby of single column with aggregate sum()

sum_group = df.groupby('city')['sales'].sum()
print("\nGroupby sum:\n", sum_group)
# Out:
# Groupby sum:
#  city
# Chennai        580
# Delhi          420
# Pondicherry    700
# Name: sales, dtype: int64

# %%
# Use Groupby of single column with aggregate count()

count_group = df.groupby('city')['sales'].count()
print("\nGroupby count:\n", count_group)
# Out:
# Groupby count:
#  city
# Chennai        3
# Delhi          3
# Pondicherry    2
# Name: sales, dtype: int64

# %%
# Use Groupby of single column with aggregate min() and max()

min_max_group = df.groupby('city')['sales'].agg(['min','max'])
print("\nGroupby min & max:\n", min_max_group)
# Out:
# Groupby min & max:
#               min  max
# city
# Chennai      150  250
# Delhi        100  200
# Pondicherry  300  400

# %%
# Use Groupby of any 2 columns with aggregate mean()
mean_group = df.groupby(['city','employees'])['sales'].mean()
print("\nGroupby two columns (mean):\n", mean_group)
# Out:
# Groupby two columns (mean):
#  city         employees
# Chennai      12           150.0
#              16           180.0
#              18           250.0
# Delhi        10           100.0
#              14           120.0
#              15           200.0
# Pondicherry  20           300.0
#              25           400.0
# Name: sales, dtype: float64

# %%
# Use Groupby of any 2 columns with aggregate min() and max()

min_max_two = df.groupby(['city','employees'])['sales'].agg(['min','max'])
print("\nGroupby two columns (min & max):\n", min_max_two)
# Out:
# Groupby two columns (min & max):
#                         min  max
# city        employees
# Chennai     12         150  150
#             16         180  180
#             18         250  250
# Delhi       10         100  100
#             14         120  120
#             15         200  200
# Pondicherry 20         300  300
#             25         400  400

# %% [markdown]
# ## Data Range

# %% [markdown]
# Create a pandas daterange where starting date is 1st of January,2020 and end date is 1st of April 2021, store it in a new variable named 'a'

# %%
# a = 
a = pd.date_range(start='2020-01-01', end='2021-04-01')

# %% [markdown]
# print a

# %%
print("Date Range:\n", a)
# Out:
# Date Range:
#  DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2021-03-23', '2021-03-24', '2021-03-25', '2021-03-26',
#                '2021-03-27', '2021-03-28', '2021-03-29', '2021-03-30',
#                '2021-03-31', '2021-04-01'],
#               dtype='datetime64[us]', length=457, freq='D')

# %% [markdown]
# What is the len of a?

# %%
import pandas as pd
a = pd.date_range(start='2020-01-01', end='2021-04-01')

print("\nLength of a:", len(a))
print("\nType of a:", type(a))
# Out:
# Length of a: 457
#
# Type of a: <class 'pandas.DatetimeIndex'>

# %% [markdown]
# What is the type of a?

# %%
print("\nType of a:", type(a))
# Out:
# Type of a: <class 'pandas.DatetimeIndex'>
